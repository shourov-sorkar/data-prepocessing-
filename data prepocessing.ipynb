# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # Apply the default seaborn theme, scaling, and color palette

import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # About Titanic Dataset
# It is one of the most popular datasets used for understanding machine learning basics. It contains information of all the passengers aboard the RMS Titanic, which unfortunately was shipwrecked. This dataset can be used to predict whether a given passenger survived or not.

# %% [markdown]
# # Load Dataset

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# ## Missing Value Treatment

# %%
titanic.head(20).isna().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age             3
# sibsp           0
# parch           0
# fare            0
# embarked        0
# class           0
# who             0
# adult_male      0
# deck           15
# embark_town     0
# alive           0
# alone           0
# dtype: int64

# %% [markdown]
# #### Here I find out the missing value on top 20 data
# ##### Here We notice that in age column there was 3 missing value and in deck column there is 15 mission value

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ##### Found the  Missing value on total dataset

# %% [markdown]
# # Drop  those Column have  Missing value

# %%
threshold = 0.5

titanic.head(20)[titanic.columns[titanic.isnull().mean() < threshold]]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# # Fill-up The Missing value

# %%
num_cols = ['age']

# %% [markdown]
# ## Here I treatment the age column and fill the missing value (Here fill the missing value with 0)

# %%
titanic.head(20)[num_cols].fillna(0)
# Out:
#      age
# 0   22.0
# 1   38.0
# 2   26.0
# 3   35.0
# 4   35.0
# 5    0.0
# 6   54.0
# 7    2.0
# 8   27.0
# 9   14.0
# 10   4.0
# 11  58.0
# 12  20.0
# 13  39.0
# 14  14.0
# 15  55.0
# 16   2.0
# 17   0.0
# 18  31.0
# 19   0.0

# %% [markdown]
# ## Here I will fill the missing value of age column with the avarage age

# %%
titanic.head(20)['age'].fillna(titanic['age'].mean())
# Out:
# 0     22.000000
# 1     38.000000
# 2     26.000000
# 3     35.000000
# 4     35.000000
# 5     29.699118
# 6     54.000000
# 7      2.000000
# 8     27.000000
# 9     14.000000
# 10     4.000000
# 11    58.000000
# 12    20.000000
# 13    39.000000
# 14    14.000000
# 15    55.000000
# 16     2.000000
# 17    29.699118
# 18    31.000000
# 19    29.699118
# Name: age, dtype: float64

# %%
for col in num_cols:
    titanic[col] = titanic[col].fillna(titanic[col].mode())
    
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## In the above Cell I filled the all numerical column with the most frequently come in that column

# %% [markdown]
# # Find out the catagorical column

# %%
cat_cols = ['deck']

# %%
titanic.head(20)['deck'].fillna(titanic['deck'].value_counts().idxmax())
# Out:
# 0     C
# 1     C
# 2     C
# 3     C
# 4     C
# 5     C
# 6     E
# 7     C
# 8     C
# 9     C
# 10    G
# 11    C
# 12    C
# 13    C
# 14    C
# 15    C
# 16    C
# 17    C
# 18    C
# 19    C
# Name: deck, dtype: category
# Categories (7, object): [A, B, C, D, E, F, G]

# %% [markdown]
# ### In the above cell I filled the missing value in  deck column with the value are maximum time found in dataset

# %% [markdown]
# #

# %% [markdown]
# # Outliers Treatment

# %% [markdown]
# ##### Detect outliers using boxplots

# %%
titanic.plot.box();

# %% [markdown]
# #### Detect outliers using density plots

# %%
titanic.plot.density();

# %% [markdown]
# ##### In the above cell is a representation of the distribution of a numeric variable. It uses a kernel density estimate to show the probability density function of the variable

# %% [markdown]
# ## Caping the outliers

# %%
def detect_outlier(feature):
    Q1 = feature.quantile(0.25)
    Q3 = feature.quantile(0.75)
    
    IQR = Q3-Q1
    
    lower_bound = Q1-(1.5*IQR)
    upper_bound = Q3+(1.5*IQR)
    
    return feature.index[(feature<lower_bound)|(feature>upper_bound)].tolist()

# %%
for col in num_cols:
    print(col,'-->',detect_outlier(titanic[col]))
# Out:
# age --> [7, 11, 15, 16, 33, 54, 78, 94, 96, 116, 119, 152, 164, 170, 172, 174, 183, 195, 205, 232, 252, 268, 275, 280, 297, 305, 326, 340, 366, 381, 386, 438, 456, 467, 469, 479, 483, 487, 492, 493, 530, 545, 555, 570, 587, 625, 626, 630, 642, 644, 647, 659, 672, 684, 694, 745, 755, 772, 788, 803, 824, 827, 829, 831, 851, 879]
